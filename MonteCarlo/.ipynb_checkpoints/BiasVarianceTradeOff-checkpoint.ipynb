# %% [markdown]
# # Bias Variance Trade-off When Determing The Proton RMS-radius from Electron Scattering Data
#
# * <b>On the determination of the proton RMS-radius from electron scattering data</b><br>
# F. Borkowski,  G.G. Simon, V. H. Walther, R.D. Wendling<br>
# Zeitschrift für Physik A Atoms and Nuclei, 275 (1975) 29-31.<br>
# https://doi.org/10.1007/BF01409496<br><br>
# <b>Abstract:</b>  "It is shown that the proton rms radius should be determined from fitting a polynomial of second order to the low-q2 form factors. The commonly used polynomial of first order yields radius values which are too small. The proton rms radius has been redetermined from an analysis of the electron scattering data measured at three laboratories. The best fit value is 0.87±0.02 fm."<br>
# <b>Comment:</b> What the authors should have said is the low q2 linear fits have a large bias and a low varaiance while the quadratic fits have a low bias and a high variance.  Also it should be stated clearly this test assumes standard dipole, which its 0.81fm radius, is correct yet this very paper extracts a radius of 0.87fm!?
#
# <b>REAL CONCLUSION</b> A linear fit with 15 data points equal spaced from 0.1 to 0.8 fm^{-2} produces nearly the same root mean square error as a quadratic fit with 31 data points equal space from 0.1 to 1.6 fm^{-2}.   When one takes into account that in order to extract G_E from the higher q2 fits also requires determining the magnetic form factor, lower q2 fits are clearly preferable for a parsimonious extraction of the proton radius in complete contradition to the conclusions of the original paper.
#
# The second problem with this papers conclusion is it implies that going to higher Q2 is better while not only using more events in the higher Q2 fits, but ignoring the fact the cross sections are smaller at high Q2.
#
# (note: next step will be to add table with equal events)

# %% [markdown]
# ## Introduction
#
# This code shows that while it is true that the first order polynomials have bias,
# if one considers the total error = bias**2 + variance, one will find exactly the
# opposite conclusion to that drawn by this classic 1975 paper which seems to be the
# source of the very complex modelings and inappropriate remarks requarding parsimonious
# models.

# %% [markdown]
# ## The Exact Example From The Z. Physics Paper

# %%
# Influence was studied by fitting pseudo data to the dipole formula

import matplotlib.pyplot as plt
import numpy as np
from lmfit import Model, Parameters

#
# Parmeters
#

minq2=[0.1,0.1,0.1,0.1] # list of minimum q2 values
maxq2=[0.4,0.8,1.2,1.6] # list of maximum q2 values
spacing=0.05            # spacing between point in fm**(-2)
error=0.005             # random error to be adding to each point
loops=100000            # number of simulations for each (minq2,maxq2) range

#
# Input Dipole Charge Form Factor
#
    
def dipole(q2):
      return (1+q2/18.23)**(-2)
true=-0.1097 # input radius

#
# Linear and Quadratic Fit Functions
#

def linear(q2,a0,a1):
    return a0+a1*q2

def quad(q2,a0,a1,a2):
    return a0+a1*q2+a2*q2**2

#
# Lists and Dictionaries For Storing Simulation Results
#

lone=[]; ltwo=[]; lthree=[]; lfour=[]; lfive=[]; qone=[]; qtwo=[]; qthree=[]; qfour=[]; qfive=[]
linear_example_result=[]; quad_example_result=[]

rlinear={'0':lone, '1':ltwo, '2':lthree, '3':lfour, '4':lfive}
rquad={'0':qone, '1':qtwo, '2':qthree, '3':qfour, '4':qfive}

#
# Monte Carlo Loop With LMFIT Of Linear and Quadratic Functions
#

for n in range(len(maxq2)):
    q2list=np.linspace(minq2[n],maxq2[n],int(np.around((maxq2[n]-minq2[n])/spacing)+1))
    print('Generating faux data at q2 points:\n ',q2list)
    for m in range(loops):
        data=dipole(q2list)+(error*np.random.randn(len(q2list)))
        model=Model(quad)
        result_quad=model.fit(data,q2=q2list,a0=1,a1=-0.11,a2=0.01,weights=1/error)
        model=Model(linear)
        result_linear=model.fit(data,q2=q2list,a0=1,a1=-0.11,weights=1/error)
        rlinear[str(n)].append([result_linear.best_values['a0'],result_linear.best_values['a1']])
        rquad[str(n)].append([result_quad.best_values['a0'],result_quad.best_values['a1'],result_quad.best_values['a2']])
        if (m+1)%200==0:
            print('.',end="")
        if (m+1)%10000==0:
            print(m+1)
    # saving one full fit object for each range
    linear_example_result.append(result_linear) 
    quad_example_result.append(result_quad)
# Out:
# Generating faux data at q2 points:
#   [0.1  0.15 0.2  0.25 0.3  0.35 0.4 ]
# ..................................................10000
# ..................................................20000
# ..................................................30000
# ..................................................40000
# ..................................................50000
# ..................................................60000
# ..................................................70000
# ..................................................80000
# ..................................................90000
# ..................................................100000
# Generating faux data at q2 points:
#   [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8 ]
# ..................................................10000
# ..................................................20000
# ..................................................30000
# ..................................................40000
# ..................................................50000
# ..................................................60000
# ..................................................70000
# ..................................................80000
# ..................................................90000
# ..................................................100000
# Generating faux data at q2 points:
#   [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2 ]
# ..................................................10000
# ..................................................20000
# ..................................................30000
# ..................................................40000
# ..................................................50000
# ..................................................60000
# ..................................................70000
# ..................................................80000
# ..................................................90000
# ..................................................100000
# Generating faux data at q2 points:
#   [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2  1.25 1.3  1.35 1.4  1.45
#  1.5  1.55 1.6 ]
# ..................................................10000
# ..................................................20000
# ..................................................30000
# ..................................................40000
# ..................................................50000
# ..................................................60000
# ..................................................70000
# ..................................................80000
# ..................................................90000
# ..................................................100000

# %% [markdown]
# <b>Note that for the lowest q2 point the radius from the mean of the values is not equal to the mean of the radii since you cannot take the sqrt. of negative numbers.</b>

# %%
print('\nSimulation result in the format shown in the Z.Phys. table.   Without showing the uncertainties, this \
table makes it look like quadratic fits should always be selected over linear fits \n')
print('| Range     | Linear     |  Quadratic |')
print('| [fm^{-2}] | a0   Radius|  a0  Radius|')

for n in range(len(maxq2)):
    la1=[];la0=[];lsum=[];qa2=[];qa1=[];aq0=[];qsum=[]
    la1=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[1])
    la0=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[0])
    lsum=la1/la0
    qa2=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[2])
    qa1=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[1])
    qa0=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[0])
    qsum=qa1/qa0
    
    print("|",minq2[n],"-",maxq2[n],"| {0:0.3f}| {1:.2f}| {2:0.3f}| {3:0.2f}|"
          .format(np.mean(la0),np.sqrt(-6*np.mean(lsum)),np.mean(qa0),np.sqrt(-6*np.mean(qsum))))

print('\nBut by simply showing the root mean square error (RMSE) it is clear that for low q2 linear fits are better.\
  In fact, this nicely illistrates not only the bias-variance trade-off, but also the fact that the best fit function\n\
is not always the true function [add math paper reference]\n')

print('| Range     | Linear                                           | Quadratic                                        |')
print('| [fm^{-2}] |   a0  | Radius|  a1/a0 |  Bias  | Sigma |  RMSE  |   a0  | Radius| a1/a0  |  Bias  | Sigma |  RMSE  |')


for n in range(len(maxq2)):
    la1=[];la0=[];lsum=[];qa2=[];qa1=[];aq0=[];qsum=[]
    la1=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[1])
    la0=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[0])
    lsum=la1/la0
    qa2=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[2])
    qa1=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[1])
    qa0=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[0])
    qsum=qa1/qa0
    
    print("|",minq2[n],"-",maxq2[n],"| {8:0.4f}| {6:.4f}| {10:0.4f}| {0:0.4f}| {1:0.4f}| {2:0.4f} | {9:0.4f}| {7:0.4f}| {11:0.4f}| {3:+0.4f}| {4:0.4f}| {5:0.4f} |"
          .format(true-np.mean(lsum),np.std(lsum),np.sqrt((true-np.mean(lsum))**2+np.std(lsum)**2),
                  true-np.mean(qsum),np.std(qsum),np.sqrt((true-np.mean(qsum))**2+np.std(qsum)**2),
                  np.sqrt(-6*np.mean(lsum)),np.sqrt(-6*np.mean(qsum)),
                  np.mean(la0),np.mean(qa0),np.mean(lsum),np.mean(qsum)))#,np.mean(1sum),np.mean(qsum)))


for n in range(len(maxq2)):
    la1=[];la0=[];lsum=[];qa2=[];qa1=[];aq0=[];qsum=[]
    la1=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[1])
    la0=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[0])
    lsum=la1/la0
    la=la1
    qa2=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[2])
    qa1=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[1])
    qa0=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[0])
    qsum=qa1/qa0
    lq=qa1
    
    plt.figure(dpi=150)
    # a1/a0 Projection 
    plt.subplot(2, 2, 1) 
    plt.title('q$^2$ from '+str(minq2[n])+' to '+str(maxq2[n])+' [fm]$^{-2}$')
    plt.hist(qsum,bins=100,range=(-0.17,-0.04)) 
    x, y, _ = plt.hist(lsum,bins=50)
    plt.xlabel('a1/a0')
    plt.ylabel('counts')
    plt.plot([true,true], [0, x.max()], 'k-', lw=2)
    plt.xlim(-0.17,-0.04)
    # Scattering Plot 
    plt.subplot(2, 2, 2) 
    plt.title('with '+str(linear_example_result[n].ndata)+' data points')
    plt.scatter(qa0,qa1,s=2,label='Quadratic')
    plt.scatter(la0,la1,s=2,label='Linear',zorder=11)
    plt.plot(1, true, marker='o', markersize=3, color="black",zorder=20)
    plt.xlabel('a0')
    plt.ylabel('a1')
    plt.tight_layout()
    plt.legend()
    plt.savefig("zresult.png")
    plt.show()
# Out:
# Simulation result in the format shown in the Z.Phys. table.   Without showing the uncertainties, this table makes it look like quadratic fits should always be selected over linear fits
#
# | Range     | Linear     |  Quadratic |
# | [fm^{-2}] | a0   Radius|  a0  Radius|
# | 0.1 - 0.4 | 1.000| 0.80| 1.000| 0.81|
# | 0.1 - 0.8 | 0.999| 0.78| 1.000| 0.81|
# | 0.1 - 1.2 | 0.997| 0.77| 1.000| 0.81|
# | 0.1 - 1.6 | 0.996| 0.76| 1.000| 0.81|
#
# But by simply showing the root mean square error (RMSE) it is clear that for low q2 linear fits are better.  In fact, this nicely illistrates not only the bias-variance trade-off, but also the fact that the best fit function
# is not always the true function [add math paper reference]
#
# | Range     | Linear                                           | Quadratic                                        |
# | [fm^{-2}] |   a0  | Radius|  a1/a0 |  Bias  | Sigma |  RMSE  |   a0  | Radius| a1/a0  |  Bias  | Sigma |  RMSE  |
# | 0.1 - 0.4 | 0.9996| 0.7951| -0.1054| -0.0043| 0.0184| 0.0189 | 1.0000| 0.8073| -0.1086| -0.0011| 0.1090| 0.1090 |
# | 0.1 - 0.8 | 0.9987| 0.7829| -0.1022| -0.0075| 0.0057| 0.0095 | 1.0000| 0.8092| -0.1091| -0.0006| 0.0281| 0.0281 |
# | 0.1 - 1.2 | 0.9975| 0.7712| -0.0991| -0.0106| 0.0030| 0.0110 | 0.9999| 0.8088| -0.1090| -0.0007| 0.0137| 0.0138 |
# | 0.1 - 1.6 | 0.9959| 0.7600| -0.0963| -0.0134| 0.0019| 0.0136 | 0.9998| 0.8074| -0.1086| -0.0011| 0.0085| 0.0085 |

# %%
   
la1=[];la0=[];lsum=[];qa2=[];qa1=[];aq0=[];qsum=[]
la1=(np.ndarray.transpose(np.asarray(rlinear['1']))[1])
la0=(np.ndarray.transpose(np.asarray(rlinear['1']))[0])
lsum=la1/la0
la=la1
qa2=(np.ndarray.transpose(np.asarray(rquad['3']))[2])
qa1=(np.ndarray.transpose(np.asarray(rquad['3']))[1])
qa0=(np.ndarray.transpose(np.asarray(rquad['3']))[0])
qsum=qa1/qa0
lq=qa1

plt.figure(dpi=150)
# a1/a0 Projection 
plt.subplot(2, 2, 1) 
plt.title('optimal q$^2$ ranges')
plt.hist(qsum,bins=100,range=(-0.17,-0.04),zorder=10,alpha=0.5) 
x, y, _ = plt.hist(lsum,bins=50,zorder=1,alpha=0.5)
plt.xlabel('a1/a0')
plt.ylabel('counts')
plt.plot([true,true], [0, x.max()], 'k-', lw=2)
plt.xlim(-0.17,-0.04)
# Scattering Plot 
plt.subplot(2, 2, 2) 
plt.title('with '+str(linear_example_result[n].ndata)+' data points')
plt.scatter(qa0,qa1,s=2,label='Quadratic')
plt.scatter(la0,la1,s=2,label='Linear',zorder=11)
plt.plot(1, true, marker='o', markersize=3, color="black",zorder=20)
plt.xlabel('a0')
plt.ylabel('a1')
plt.tight_layout()
plt.legend()
plt.show()

# %%
for n in range(len(maxq2)):
    print(linear_example_result[n].fit_report())
    linear_example_result[n].plot()
    plt.ylabel('G$_E$')
    plt.show()
    print(quad_example_result[n].fit_report())
    quad_example_result[n].plot()
    plt.ylabel('G$_E$')
    plt.show()
# Out:
# [[Model]]
#     Model(linear)
# [[Fit Statistics]]
#     # function evals   = 9
#     # data points      = 7
#     # variables        = 2
#     chi-square         = 3.811
#     reduced chi-square = 0.762
#     Akaike info crit   = -0.257
#     Bayesian info crit = -0.365
# [[Variables]]
#     a0:   0.99406300 +/- 0.004442 (0.45%) (init= 1)
#     a1:  -0.08656914 +/- 0.016498 (19.06%) (init=-0.11)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a0, a1)                    = -0.928
# [[Model]]
#     Model(quad)
# [[Fit Statistics]]
#     # function evals   = 11
#     # data points      = 7
#     # variables        = 3
#     chi-square         = 3.405
#     reduced chi-square = 0.851
#     Akaike info crit   = 0.955
#     Bayesian info crit = 0.792
# [[Variables]]
#     a0:   1.00136290 +/- 0.011565 (1.15%) (init= 1)
#     a1:  -0.15609195 +/- 0.102161 (65.45%) (init=-0.11)
#     a2:   0.13904562 +/- 0.201324 (144.79%) (init= 0.01)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a1, a2)                    = -0.985
#     C(a0, a1)                    = -0.965
#     C(a0, a2)                    =  0.914
# [[Model]]
#     Model(linear)
# [[Fit Statistics]]
#     # function evals   = 8
#     # data points      = 15
#     # variables        = 2
#     chi-square         = 8.692
#     reduced chi-square = 0.669
#     Akaike info crit   = -4.184
#     Bayesian info crit = -2.768
# [[Variables]]
#     a0:   0.99685222 +/- 0.002439 (0.24%) (init= 1)
#     a1:  -0.09494317 +/- 0.004886 (5.15%) (init=-0.11)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a0, a1)                    = -0.902
# [[Model]]
#     Model(quad)
# [[Fit Statistics]]
#     # function evals   = 11
#     # data points      = 15
#     # variables        = 3
#     chi-square         = 6.963
#     reduced chi-square = 0.580
#     Akaike info crit   = -5.511
#     Bayesian info crit = -3.387
# [[Variables]]
#     a0:   1.00323338 +/- 0.004338 (0.43%) (init= 1)
#     a1:  -0.13179690 +/- 0.021827 (16.56%) (init=-0.11)
#     a2:   0.04094858 +/- 0.023719 (57.93%) (init= 0.01)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a1, a2)                    = -0.978
#     C(a0, a1)                    = -0.932
#     C(a0, a2)                    =  0.852
# [[Model]]
#     Model(linear)
# [[Fit Statistics]]
#     # function evals   = 8
#     # data points      = 23
#     # variables        = 2
#     chi-square         = 27.108
#     reduced chi-square = 1.291
#     Akaike info crit   = 7.780
#     Bayesian info crit = 10.051
# [[Variables]]
#     a0:   0.99883424 +/- 0.002606 (0.26%) (init= 1)
#     a1:  -0.09843678 +/- 0.003571 (3.63%) (init=-0.11)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a0, a1)                    = -0.891
# [[Model]]
#     Model(quad)
# [[Fit Statistics]]
#     # function evals   = 11
#     # data points      = 23
#     # variables        = 3
#     chi-square         = 21.520
#     reduced chi-square = 1.076
#     Akaike info crit   = 4.470
#     Bayesian info crit = 7.877
# [[Variables]]
#     a0:   1.00668450 +/- 0.004186 (0.42%) (init= 1)
#     a1:  -0.13109385 +/- 0.014696 (11.21%) (init=-0.11)
#     a2:   0.02512081 +/- 0.011023 (43.88%) (init= 0.01)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a1, a2)                    = -0.975
#     C(a0, a1)                    = -0.915
#     C(a0, a2)                    =  0.823
# [[Model]]
#     Model(linear)
# [[Fit Statistics]]
#     # function evals   = 8
#     # data points      = 31
#     # variables        = 2
#     chi-square         = 21.628
#     reduced chi-square = 0.746
#     Akaike info crit   = -7.160
#     Bayesian info crit = -4.292
# [[Variables]]
#     a0:   0.99777593 +/- 0.001665 (0.17%) (init= 1)
#     a1:  -0.09704199 +/- 0.001734 (1.79%) (init=-0.11)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a0, a1)                    = -0.885
# [[Model]]
#     Model(quad)
# [[Fit Statistics]]
#     # function evals   = 11
#     # data points      = 31
#     # variables        = 3
#     chi-square         = 20.548
#     reduced chi-square = 0.734
#     Akaike info crit   = -6.749
#     Bayesian info crit = -2.447
# [[Variables]]
#     a0:   1.00050648 +/- 0.002791 (0.28%) (init= 1)
#     a1:  -0.10592609 +/- 0.007521 (7.10%) (init=-0.11)
#     a2:   0.00522593 +/- 0.004307 (82.42%) (init= 0.01)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a1, a2)                    = -0.973
#     C(a0, a1)                    = -0.905
#     C(a0, a2)                    =  0.806

# %% [markdown]
# <b>Input Radius Was 0.81132 fm (an a1 term of 0.10971)</b><br>
# By focusing solely on the bias the authors completely missed the fact, the variance of
# the low q2 fit had an enormous varaince.  In fact, their next step is to further increase
# model complexity by added three more parameters (floating normalization).

# %% [markdown]
# ## Equal Counts In Each Range
#
# This is already a bit misleading as I am putting more then twice the events in the higher Q2 cut when we all know the cross section fall rapidly with the Mott cross section; so next we repeat the exercise with equal events spaced between the limits.   In other words, it requires far less beam time to take low Q2 data then to take high Q2 data.

# %%
import matplotlib.pyplot as plt
import numpy as np
from lmfit import Model, Parameters

def dipole(q2):
      return (1+q2/18.23)**(-2)
true=-0.1097 # input radius


def linear(q2,a0,a1):
    return a0+a1*q2

def quad(q2,a0,a1,a2):
    return a0+a1*q2+a2*q2**2


minq2=[0.1,0.1,0.1,0.1]
maxq2=[0.4,0.8,1.2,1.6]

spacing=0.05
error=0.005 
loops=100000

# I should make this dynamic
lone=[]; ltwo=[]; lthree=[]; lfour=[]
qone=[]; qtwo=[]; qthree=[]; qfour=[]

rlinear={'0':lone,
         '1':ltwo,
         '2':lthree,
         '3':lfour}

rquad={'0':qone,
       '1':qtwo,
       '2':qthree,
       '3':qfour}

linear_example_result=[]
quad_example_result=[]

fit_params = Parameters()
fit_params.add('a0',  value= 1.00)
fit_params.add('a1',  value= -0.11)
fit_params.add('a2',  value= 0.0125)

for n in range(len(maxq2)):
    q2list=np.linspace(minq2[n],maxq2[n],int(np.around((maxq2[n]-minq2[n])/spacing)+1))
    print('Generating faux data at q2 points:\n ',q2list)
    #q2list=np.linspace(minq2[n],maxq2[n],len(data))
    #print('Generating faux data at q2 points:\n ',q2list)
    for m in range(loops):
        data=dipole(q2list)*(1+error*np.random.randn(len(q2list)))
        #data=data*(1+0.00*np.random.randn())
        model=Model(quad)
        #result_quad=model.fit(data,q2=q2list,a0=1,a1=-0.11,a2=0.01,weights=1/error)
        result_quad=model.fit(data,q2=q2list,params=fit_params,weights=1/error)
        model=Model(linear)
        result_linear=model.fit(data,q2=q2list,a0=1,a1=-0.11,weights=1/error)
        #results.append([result_linear,result_quad]) 
        #rlinear[str(n)].append(result_linear)
        #rquad[str(n)].append(result_quad)
        rlinear[str(n)].append([result_linear.best_values['a0'],result_linear.best_values['a1']])
        rquad[str(n)].append([result_quad.best_values['a0'],result_quad.best_values['a1'],result_quad.best_values['a2']])
    # saving one full fit object for each range
    linear_example_result.append(result_linear) 
    quad_example_result.append(result_quad)
# Out:
# Generating faux data at q2 points:
#   [0.1  0.15 0.2  0.25 0.3  0.35 0.4 ]
# Generating faux data at q2 points:
#   [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8 ]
# Generating faux data at q2 points:
#   [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2 ]
# Generating faux data at q2 points:
#   [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65 0.7  0.75
#  0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15 1.2  1.25 1.3  1.35 1.4  1.45
#  1.5  1.55 1.6 ]

# %%
print('\n Simulation results. \n')
print('| Range     | Linear     |  Quadratic |')
print('| [fm^{-2}] | a0   Radius|  a0  Radius|')

for n in range(len(maxq2)):
    la1=[];la0=[];lsum=[];qa2=[];qa1=[];aq0=[];qsum=[]
    la1=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[1])
    la0=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[0])
    lsum=la1/la0
    qa2=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[2])
    qa1=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[1])
    qa0=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[0])
    qsum=qa1/qa0
    
    print("|",minq2[n],"-",maxq2[n],"| {0:0.3f}| {1:.2f}| {2:0.3f}| {3:0.2f}|"
          .format(np.mean(la0),np.sqrt(-6*np.mean(lsum)),np.mean(qa0),np.sqrt(-6*np.mean(qsum))))

print('\n Putting both the bias and variance together shows that the picture is not so clear cut.\n')

print('| Range     | Linear                                           | Quadratic                                        |')
print('| [fm^{-2}] |   a0  | Radius|  a1/a0 |  Bias  | Sigma |  RMSE  |   a0  | Radius| a1/a0  |  Bias|  Sigma  |  RMSE  |')


for n in range(len(maxq2)):
    la1=[];la0=[];lsum=[];qa2=[];qa1=[];aq0=[];qsum=[]
    la1=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[1])
    la0=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[0])
    lsum=la1/la0
    qa2=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[2])
    qa1=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[1])
    qa0=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[0])
    qsum=qa1/qa0
    
    print("|",minq2[n],"-",maxq2[n],"| {8:0.4f}| {6:.4f}| {10:0.4f}| {0:0.4f}| {1:0.4f}| {2:0.4f} | {9:0.4f}| {7:0.4f}| {11:0.4f}| {3:0.4f}| {4:0.4f}| {5:0.4f} |"
          .format(true-np.mean(lsum),np.std(lsum),np.sqrt((true-np.mean(lsum))**2+np.std(lsum)**2),
                  true-np.mean(qsum),np.std(qsum),np.sqrt((true-np.mean(qsum))**2+np.std(qsum)**2),
                  np.sqrt(-6*np.mean(lsum)),np.sqrt(-6*np.mean(qsum)),
                  np.mean(la0),np.mean(qa0),np.mean(lsum),np.mean(qsum)))#,np.mean(1sum),np.mean(qsum)))


for n in range(len(maxq2)):
    la1=[];la0=[];lsum=[];qa2=[];qa1=[];aq0=[];qsum=[]
    la1=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[1])
    la0=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[0])
    lsum=la1/la0
    la=la1
    qa2=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[2])
    qa1=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[1])
    qa0=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[0])
    qsum=qa1/qa0
    lq=qa1
    
    plt.figure(dpi=150)
    plt.subplot(2, 2, 1) 
    plt.title('q$^2$ from '+str(minq2[n])+' to '+str(maxq2[n])+' [fm]$^{-2}$')
    plt.hist(qsum,bins=100,range=(-0.2,-0.05)) 
    x, y, _ = plt.hist(lsum,bins=50)
    #plt.yscale('log')
    plt.xlabel('a1/a0')
    plt.ylabel('counts')
    plt.plot([true,true], [0, x.max()], 'k-', lw=2)
    plt.subplot(2, 2, 2) 
    plt.title('with '+str(linear_example_result[n].ndata)+' data points')
    plt.scatter(qa0,qa1,s=2,label='Quadratic')
    plt.scatter(la0,la1,s=2,label='Linear',zorder=11)
    plt.plot(1, true, marker='o', markersize=3, color="black",zorder=20)
    plt.xlabel('a0')
    plt.ylabel('a1')
    plt.tight_layout()
    plt.legend()
    plt.show()
# Out:
#  Simulation results.
#
# | Range     | Linear     |  Quadratic |
# | [fm^{-2}] | a0   Radius|  a0  Radius|
# | 0.1 - 0.4 | 1.000| 0.80| 1.001| 0.83|
# | 0.1 - 0.8 | 0.999| 0.78| 1.000| 0.81|
# | 0.1 - 1.2 | 0.998| 0.77| 1.000| 0.81|
# | 0.1 - 1.6 | 0.996| 0.76| 1.000| 0.81|
#
#  Putting both the bias and variance together shows that the picture is not so clear cut.
#
# | Range     | Linear                                           | Quadratic                                        |
# | [fm^{-2}] |   a0  | Radius|  a1/a0 |  Bias  | Sigma |  RMSE  |   a0  | Radius| a1/a0  |  Bias|  Sigma  |  RMSE  |
# | 0.1 - 0.4 | 0.9997| 0.7967| -0.1058| -0.0039| 0.0182| 0.0186 | 1.0007| 0.8303| -0.1149| 0.0052| 0.1072| 0.1073 |
# | 0.1 - 0.8 | 0.9988| 0.7836| -0.1023| -0.0074| 0.0053| 0.0091 | 1.0002| 0.8140| -0.1104| 0.0007| 0.0269| 0.0269 |
# | 0.1 - 1.2 | 0.9975| 0.7714| -0.0992| -0.0105| 0.0029| 0.0109 | 0.9998| 0.8066| -0.1084| -0.0013| 0.0130| 0.0131 |
# | 0.1 - 1.6 | 0.9959| 0.7600| -0.0963| -0.0134| 0.0017| 0.0135 | 0.9998| 0.8077| -0.1087| -0.0010| 0.0080| 0.0081 |

# %% [markdown]
# ## Showing The Effect Of Floating The Normalizations

# %%
import matplotlib.pyplot as plt
import numpy as np
from lmfit import Model, Parameters

def dipole(q2):
      return (1+q2/18.23)**(-2)
#      return (1+0.1176*q2/2)**(-2)
true=-0.1097 # input radius


def linear(q2,a0,a1):
    return a0*(1+a1*q2)

def quad(q2,a0,a1,a2):
    return a0*(1+a1*q2+a2*q2**2)

def fixedquad(q2,a0,a1,a2):
    return (1+a1*q2+a2*q2**2)

def fixedlinear(q2,a0,a1):
    return (1+a1*q2)

def fitdipole(q2,a0,a1):
    return a0*(1-a1*q2/2)**(-2) 

minq2=0.1
maxq2=0.4

#spacing=0.01
#error=0.01
#loops=100000

spacing=0.01
error=0.003
#loops=1000
loops=250
#loops=25

# I should make this dynamic
lone=[]; ltwo=[]; lthree=[]; lfour=[]
qone=[]; qtwo=[]; qthree=[]; qfour=[]

rlinear={'0':lone,
         '1':ltwo,
         '2':lthree,
         '3':lfour}

rquad={'0':qone,
       '1':qtwo,
       '2':qthree,
       '3':qfour}

linear_example_result=[]
quad_example_result=[]

fit_params = Parameters()
fit_params.add('a0',  value= 1.00)
fit_params.add('b0',  value= 1.00)
fit_params.add('a1',  value= -0.11)
fit_params.add('a2',  value= 0.0125)

np.random.seed(86)

n=0
q2list=np.linspace(minq2,maxq2,int(np.around((maxq2-minq2)/spacing)+1))
print('Generating faux data at q2 points:\n ',q2list)
for m in range(loops):
        data=dipole(q2list)+error*np.random.randn(len(q2list))
        #data=data*(1+0.00*np.random.randn())
        #model=Model(fitdipole)
        model=Model(quad)
        result_quad=model.fit(data,q2=q2list,a0=1,a1=-0.11,a2=0,weights=1/error)
        model=Model(linear)
        result_linear=model.fit(data,q2=q2list,a0=1,a1=-0.11,weights=1/error)
        model=Model(quad)
        result_tquad=model.fit(data,q2=q2list,a0=1,a1=-0.11,a2=0,weights=1/error)
        #results.append([result_linear,result_quad]) 
        #rlinear.append(result_linear)
        #rquad.append(result_quad)
        linear_example_result.append(result_linear) 
        quad_example_result.append(result_quad)     
        rlinear[str(n)].append([result_linear.best_values['a0'],result_linear.best_values['a1']])
        rquad[str(n)].append([result_quad.best_values['a0'],result_quad.best_values['a1'],result_quad.best_values['a2']])
        if m%100 == 0:
            print('.',end='')
        if m%10000 == 0:
            print(m,end='')
#linear_example_result.append(result_linear) 
#quad_example_result.append(result_quad)
# Out:
# Generating faux data at q2 points:
#   [0.1  0.11 0.12 0.13 0.14 0.15 0.16 0.17 0.18 0.19 0.2  0.21 0.22 0.23
#  0.24 0.25 0.26 0.27 0.28 0.29 0.3  0.31 0.32 0.33 0.34 0.35 0.36 0.37
#  0.38 0.39 0.4 ]
# .0..

# %%
print('\n Simulation results for ',len(q2list),' points. \n')
print('| Range     | Linear     |  Dipole    |')
print('| [fm^{-2}] | a0   Radius|  n0  Radius|')

la1=[];la0=[];lsum=[];qa2=[];qa1=[];aq0=[];qsum=[]
la1=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[1])
la0=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[0])
lsum=la1/la0
qa2=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[2])
qa1=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[1])
qa0=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[0])
#qsum=qa1/qa0
qsum=qa1
    
print("|",minq2,"-",maxq2,"| {0:0.3f}| {1:.2f}| {2:0.3f}| {3:0.2f}|"
          .format(np.mean(la0),np.sqrt(-6*np.mean(lsum)),np.mean(qa0),np.sqrt(-6*np.mean(qa1))))

print('\n Putting both the bias and variance together shows that the picture is not so clear cut.\n')

print('| Range     | Linear                                           | Dipole                                          |')
print('| [fm^{-2}] |   a0  | Radius|  a1/a0 |  Bias  | Sigma |  RMSE  |   n0  | Radius|   b1   |  Bias | Sigma |  RMSE  |')


la1=[];la0=[];lsum=[];qa2=[];qa1=[];aq0=[];qsum=[]
la1=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[1])
la0=(np.ndarray.transpose(np.asarray(rlinear[str(n)]))[0])
lsum=la1/la0
qa2=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[2])
qa1=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[1])
qa0=(np.ndarray.transpose(np.asarray(rquad[str(n)]))[0])
#qsum=qa1/qa0
qsum=qa1
    
print("|",minq2,"-",maxq2,"| {8:0.4f}| {6:.4f}| {10:0.4f}| {0:0.4f}| {1:0.4f}| {2:0.4f} | {9:0.4f}| {7:0.4f}| {11:0.4f}| {3:0.4f}| {4:0.4f}| {5:0.4f} |"
          .format(true-np.mean(lsum),np.std(lsum),np.sqrt((true-np.mean(lsum))**2+np.std(lsum)**2),
                  true-np.mean(qsum),np.std(qsum),np.sqrt((true-np.mean(qsum))**2+np.std(qsum)**2),
                  np.sqrt(-6*np.mean(lsum)),np.sqrt(-6*np.mean(qa1)),
                  np.mean(la0),np.mean(qa0),np.mean(lsum),np.mean(qa1)))#,np.mean(1sum),np.mean(qsum)))
# Out:
#  Simulation results for  31  points.
#
# | Range     | Linear     |  Dipole    |
# | [fm^{-2}] | a0   Radius|  n0  Radius|
# | 0.1 - 0.4 | 0.999| 0.79| 1.000| 0.80|
#
#  Putting both the bias and variance together shows that the picture is not so clear cut.
#
# | Range     | Linear                                           | Dipole                                          |
# | [fm^{-2}] |   a0  | Radius|  a1/a0 |  Bias  | Sigma |  RMSE  |   n0  | Radius|   b1   |  Bias | Sigma |  RMSE  |
# | 0.1 - 0.4 | 0.9994| 0.7938| -0.1050| -0.0047| 0.0056| 0.0073 | 0.9996| 0.8009| -0.1069| -0.0028| 0.0351| 0.0353 |

# %%
#result_quad.plot()
#result_linear.plot()
#plt.show()

import numpy as np
import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams['axes.labelsize'] = 15 

q2list2=np.linspace(0.,1.0,100)

plt.figure(dpi=150)

plt.subplot(2,1,1)
for i in range(len(qa0)):
    plt.plot(q2list2,fixedlinear(q2list2,la0[i],la1[i]),color='gray',zorder=1,lw=0.1)
plt.plot(q2list2,dipole(q2list2),'-',lw=2,label='True Function',color='blue')
plt.plot(q2list2,fixedlinear(q2list2,**result_linear.best_values),'-',lw=2,label='Linear Fit',color='black')
plt.errorbar(q2list,data/result_linear.best_values['a0'],yerr=error,fmt='o',color='black')#,label='Renormalized Data')
plt.legend(frameon=0,loc=1)
#plt.xlabel('Q$^2$ [fm$^{-2}$]')
plt.annotate('$\chi^2   = 30.2$',xy=(0.02,0.969)),
plt.annotate('reduced $\chi^2 = 1.04$',xy=(0.02,0.961)),
#plt.annotate('$\chi^2  = 30.2 $',xy=(0.02,0.961)),
plt.annotate('AIC = 3.1',xy=(0.02,0.953)),
plt.annotate('BIC = 6.0',xy=(0.02,0.945)),
plt.annotate('Linear Fit - Initial Radius = %0.2f fm'%(np.sqrt(-6*linear_example_result[i].best_values['a1'])-0.81),xy=(0.13,0.942),color='blue',zorder=11),
plt.ylabel('G$_E$')
plt.ylim(0.94,1.01)
plt.xlim(0,0.5)

plt.subplot(2,1,2)
for i in range(len(qa0)):
    plt.plot(q2list2,fixedquad(q2list2,qa0[i],qa1[i],qa2[i]),'-',color='gray',zorder=1,lw=0.1)
#plt.plot(q2list2,dipole(q2list2,**result_quad.best_values),'-',lw=3,label='Generating Function')
plt.plot(q2list2,dipole(q2list2),'-',lw=2,label='True Function',color='blue')
#plt.plot(q2list2,linear(q2list2,**result_linear.best_values),'--',lw=3,label='Linear Fit')
plt.plot(q2list2,fixedquad(q2list2,**result_tquad.best_values),'-',lw=2,label='Quadratic Fit',color='black')
#plt.errorbar(q2list,data,yerr=error,fmt='o',color='black')
plt.errorbar(q2list,data/result_tquad.best_values['a0'],yerr=error,fmt='o',color='black')#,label='Renormalized Data')
plt.legend(frameon=0,loc=1)
plt.xlabel('Q$^2$ [fm$^{-2}$]')
plt.ylabel('G$_E$')
plt.xlim(0,0.5)
plt.ylim(0.94,1.01)
plt.annotate('$\chi^2   = 29.6$',xy=(0.02,0.969)),
plt.annotate('reduced $\chi^2 = 1.06$',xy=(0.02,0.961)),
plt.annotate('AIC = 4.6',xy=(0.02,0.953)),
plt.annotate('BIC = 8.9',xy=(0.02,0.945)),
#plt.annotate('AIC = 4.6',xy=(0.02,0.961)),
#plt.annotate('BIC = 8.9',xy=(0.02,0.953)),
#plt.annotate('reduced $\chi^2 = 1.04$',xy=(0.02,0.945)),
plt.annotate('Quadratic Fit - Initial Radius = %0.2f fm'%(np.sqrt(-6*quad_example_result[i].best_values['a1'])-0.81),xy=(0.114,0.942),color=('blue'),zorder=11),
plt.tight_layout()
plt.savefig('linearVSquadratic-band.pdf')
plt.show()

# %%
print(result_linear.fit_report())
print(result_quad.fit_report())
# Out:
# [[Model]]
#     Model(linear)
# [[Fit Statistics]]
#     # function evals   = 11
#     # data points      = 31
#     # variables        = 2
#     chi-square         = 30.189
#     reduced chi-square = 1.041
#     Akaike info crit   = 3.178
#     Bayesian info crit = 6.046
# [[Variables]]
#     a0:   1.00159600 +/- 0.001631 (0.16%) (init= 1)
#     a1:  -0.11350171 +/- 0.005962 (5.25%) (init=-0.11)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a0, a1)                    = -0.938
#
# [[Model]]
#     Model(quad)
# [[Fit Statistics]]
#     # function evals   = 15
#     # data points      = 31
#     # variables        = 3
#     chi-square         = 29.646
#     reduced chi-square = 1.059
#     Akaike info crit   = 4.616
#     Bayesian info crit = 8.918
# [[Variables]]
#     a0:   1.00462309 +/- 0.004538 (0.45%) (init= 1)
#     a1:  -0.14080340 +/- 0.038494 (27.34%) (init=-0.11)
#     a2:   0.05528738 +/- 0.077015 (139.30%) (init= 0)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(a1, a2)                    = -0.988
#     C(a0, a1)                    = -0.973
#     C(a0, a2)                    =  0.931

# %%
def animate1(frame):
    i=frame
    plt.clf()
    plt.subplot(2,1,1)
    for j in range(i):
        plt.plot(q2list2,fixedlinear(q2list2,la0[j],la1[j]),color='gray',zorder=1,lw=0.1)
    plt.plot(q2list2,dipole(q2list2),'-',lw=2,color='blue',label='True Function')
    plt.errorbar(q2list,linear_example_result[i].data/linear_example_result[i].best_values['a0'],yerr=error,fmt='o',color='black')#,label='Renormalized Data')
    plt.plot(q2list2,fixedlinear(q2list2,**linear_example_result[i].best_values),color='black',zorder=1,lw=2,label='Linear Fit')
    plt.legend(frameon=0,loc=1)
    #plt.xlabel('Q$^2$ [fm$^{-2}$]')
    #plt.annotate('$\chi^2   = XXX$',xy=(0.02,0.969)),
    #plt.annotate('reduced $\chi^2 = XXX$',xy=(0.02,0.961)),
    #plt.annotate('AIC = XX',xy=(0.02,0.953)),
    #plt.annotate('BIC = XX',xy=(0.02,0.945)),
    plt.ylabel('G$_E$')
    plt.ylim(0.94,1.01)
    plt.xlim(0,0.5)
    #plt.annotate('$\chi^2   = 29.6$',xy=(0.02,0.969)),
    #plt.annotate('reduced $\chi^2 = 1.06$',xy=(0.02,0.961)),
    #plt.annotate('AIC = %0.3f'%linear_example_result[i].aic,xy=(0.02,0.953)),
    #plt.annotate('BIC = 8.9',xy=(0.02,0.945)),
    plt.annotate('$\chi^2$ = %0.2f '%(linear_example_result[i].chisqr),xy=(0.02,0.969)),
    plt.annotate('reduced $\chi^2$ = %0.2f'%(linear_example_result[i].redchi),xy=(0.02,0.961),color='black'),
    plt.annotate('AIC = %0.2f '%(linear_example_result[i].aic),xy=(0.02,0.953),color='black'),
    plt.annotate('BIC = %0.2f '%(linear_example_result[i].bic),xy=(0.02,0.945),color='black'),
    plt.annotate('Linear Fit - Initial Radius = %0.2f fm'%(np.sqrt(-6*linear_example_result[i].best_values['a1'])-0.81),xy=(0.13,0.942),color='blue',zorder=11),
#def animate2(frame):
    #i=frame
    #print(i)
    #plt.cla() 
    plt.subplot(2,1,2)
    for j in range(i):
        plt.plot(q2list2,fixedquad(q2list2,qa0[j],qa1[j],qa2[j]),'-',color='gray',zorder=1,lw=0.1)
    plt.plot(q2list2,dipole(q2list2),'-',lw=2,color='blue',label='True Function')
    plt.errorbar(q2list,quad_example_result[i].data/quad_example_result[i].best_values['a0'],yerr=error,fmt='o',color='black')#,label='Renormalized Data')
    plt.plot(q2list2,fixedquad(q2list2,**quad_example_result[i].best_values),color='black',zorder=1,lw=2,label='Quadratic Fit')
    plt.legend(frameon=0,loc=1)
    plt.xlabel('Q$^2$ [fm$^{-2}$]')
    plt.annotate('$\chi^2$ = %0.2f '%(quad_example_result[i].chisqr),xy=(0.02,0.9685)),
    plt.annotate('reduced $\chi^2$ = %0.2f'%(quad_example_result[i].redchi),xy=(0.02,0.961),color='black'),
    plt.annotate('AIC = %0.2f '%(quad_example_result[i].aic),xy=(0.02,0.953),color='black'),
    plt.annotate('BIC = %0.2f '%(quad_example_result[i].bic),xy=(0.02,0.945),color='black'),
    plt.annotate('Quadratic Fit - Initial Radius = %0.2f fm'%(np.sqrt(-6*quad_example_result[i].best_values['a1'])-0.81),xy=(0.114,0.942),color=('blue'),zorder=11),
    plt.ylabel('G$_E$')
    plt.ylim(0.94,1.01)
    plt.xlim(0,0.5)
    plt.tight_layout()
#    plt.show()

# %%
print(type(q2list2))
# Out:
# <class 'numpy.ndarray'>

# %%
from matplotlib import animation
fig=plt.figure(dpi=150)#,figsize=[6,2])
anim = animation.FuncAnimation(fig, animate1, frames=250, repeat=False)#,blit=True)
anim.save('floating_norm_demo.gif', writer='imagemagick', fps=1)
#fig=plt.figure(dpi=150,figsize=[6,2])
#anim = animation.FuncAnimation(fig, animate2, frames=25, )#,blit=True)
#anim.save('demoanimation2.gif', writer='imagemagick', fps=4);

# %% [markdown]
# # Need To Create Frequentist Version

# %%
def animate1(frame):
    i=frame
    plt.clf()
    plt.subplot(2,1,1)
    for j in range(i):
        plt.plot(q2list2,linear(q2list2,la0[j],la1[j]),color='gray',zorder=1,lw=0.1)
    plt.plot(q2list2,dipole(q2list2),'-',lw=2,color='blue',label='True Function')
    plt.errorbar(q2list,linear_example_result[i].data,yerr=error,fmt='o',color='black')#,label='Renormalized Data')
    plt.plot(q2list2,linear(q2list2,**linear_example_result[i].best_values),color='black',zorder=1,lw=2,label='Linear Fit')
    plt.legend(frameon=0,loc=1)
    #plt.xlabel('Q$^2$ [fm$^{-2}$]')
    #plt.annotate('$\chi^2   = XXX$',xy=(0.02,0.969)),
    #plt.annotate('reduced $\chi^2 = XXX$',xy=(0.02,0.961)),
    #plt.annotate('AIC = XX',xy=(0.02,0.953)),
    #plt.annotate('BIC = XX',xy=(0.02,0.945)),
    plt.ylabel('a$_0$ G$_E$')
    plt.ylim(0.94,1.01)
    plt.xlim(0,0.5)
    #plt.annotate('$\chi^2   = 29.6$',xy=(0.02,0.969)),
    #plt.annotate('reduced $\chi^2 = 1.06$',xy=(0.02,0.961)),
    #plt.annotate('AIC = %0.3f'%linear_example_result[i].aic,xy=(0.02,0.953)),
    #plt.annotate('BIC = 8.9',xy=(0.02,0.945)),
    plt.annotate('$\chi^2$ = %0.2f '%(linear_example_result[i].chisqr),xy=(0.02,0.969)),
    plt.annotate('reduced $\chi^2$ = %0.2f'%(linear_example_result[i].redchi),xy=(0.02,0.961),color='black'),
    plt.annotate('AIC = %0.2f '%(linear_example_result[i].aic),xy=(0.02,0.953),color='black'),
    plt.annotate('BIC = %0.2f '%(linear_example_result[i].bic),xy=(0.02,0.945),color='black'),
    plt.annotate('Linear Fit - Initial Radius = %0.2f fm'%(np.sqrt(-6*linear_example_result[i].best_values['a1'])-0.81),xy=(0.13,0.942),color='blue',zorder=11),
#def animate2(frame):
    #i=frame
    #print(i)
    #plt.cla() 
    plt.subplot(2,1,2)
    for j in range(i):
        plt.plot(q2list2,quad(q2list2,qa0[j],qa1[j],qa2[j]),'-',color='gray',zorder=1,lw=0.1)
    plt.plot(q2list2,dipole(q2list2),'-',lw=2,color='blue',label='True Function')
    plt.errorbar(q2list,quad_example_result[i].data,yerr=error,fmt='o',color='black')#,label='Renormalized Data')
    plt.plot(q2list2,quad(q2list2,**quad_example_result[i].best_values),color='black',zorder=1,lw=2,label='Quadratic Fit')
    plt.legend(frameon=0,loc=1)
    plt.xlabel('Q$^2$ [fm$^{-2}$]')
    plt.annotate('$\chi^2$ = %0.2f '%(quad_example_result[i].chisqr),xy=(0.02,0.9685)),
    plt.annotate('reduced $\chi^2$ = %0.2f'%(quad_example_result[i].redchi),xy=(0.02,0.961),color='black'),
    plt.annotate('AIC = %0.2f '%(quad_example_result[i].aic),xy=(0.02,0.953),color='black'),
    plt.annotate('BIC = %0.2f '%(quad_example_result[i].bic),xy=(0.02,0.945),color='black'),
    plt.annotate('Quadratic Fit - Initial Radius = %0.2f fm'%(np.sqrt(-6*quad_example_result[i].best_values['a1'])-0.81),xy=(0.114,0.942),color=('blue'),zorder=11),
    plt.ylabel('a$_0$ G$_E$')
    plt.ylim(0.94,1.01)
    plt.xlim(0,0.5)
    plt.tight_layout()
#    plt.show()

# %%
from matplotlib import animation
fig=plt.figure(dpi=150)#,figsize=[6,2])
anim = animation.FuncAnimation(fig, animate1, frames=250, repeat=False)#,blit=True)
anim.save('animation_frequentist.gif', writer='imagemagick', fps=1)
#fig=plt.figure(dpi=150,figsize=[6,2])
#anim = animation.FuncAnimation(fig, animate2, frames=25, )#,blit=True)
#anim.save('demoanimation2.gif', writer='imagemagick', fps=4);

# %%
plt.figure(dpi=150)

plt.subplot(2,1,1)
for i in range(len(qa0)):
    plt.plot(q2list2,linear(q2list2,la0[i],la1[i]),color='gray',zorder=1,lw=0.1)
plt.plot(q2list2,dipole(q2list2),'-',lw=2,label='True Function',color='blue')
plt.plot(q2list2,linear(q2list2,**result_linear.best_values),'-',lw=2,label='Linear Fit',color='black')
plt.errorbar(q2list,data,yerr=error,fmt='o',color='black')#,label='Renormalized Data')
plt.legend(frameon=0,loc=1)
#plt.xlabel('Q$^2$ [fm$^{-2}$]')
plt.annotate('$\chi^2   = 30.2$',xy=(0.02,0.969)),
plt.annotate('reduced $\chi^2 = 1.04$',xy=(0.02,0.961)),
#plt.annotate('$\chi^2  = 30.2 $',xy=(0.02,0.961)),
plt.annotate('AIC = 3.1',xy=(0.02,0.953)),
plt.annotate('BIC = 6.0',xy=(0.02,0.945)),
plt.annotate('Linear Fit - Initial Radius = %0.2f fm'%(np.sqrt(-6*linear_example_result[i].best_values['a1'])-0.81),xy=(0.13,0.942),color='blue',zorder=11),
plt.ylabel('$a_0$ G$_E$')
plt.ylim(0.94,1.01)
plt.xlim(0,0.5)

plt.subplot(2,1,2)
for i in range(len(qa0)):
    plt.plot(q2list2,quad(q2list2,qa0[i],qa1[i],qa2[i]),'-',color='gray',zorder=1,lw=0.1)
#plt.plot(q2list2,dipole(q2list2,**result_quad.best_values),'-',lw=3,label='Generating Function')
plt.plot(q2list2,dipole(q2list2),'-',lw=2,label='True Function',color='blue')
#plt.plot(q2list2,linear(q2list2,**result_linear.best_values),'--',lw=3,label='Linear Fit')
plt.plot(q2list2,quad(q2list2,**result_tquad.best_values),'-',lw=2,label='Quadratic Fit',color='black')
#plt.errorbar(q2list,data,yerr=error,fmt='o',color='black')
plt.errorbar(q2list,data,yerr=error,fmt='o',color='black')#,label='Renormalized Data')
plt.legend(frameon=0,loc=1)
plt.xlabel('Q$^2$ [fm$^{-2}$]')
plt.ylabel('a$_0$ G$_E$')
plt.xlim(0,0.5)
plt.ylim(0.94,1.01)
plt.annotate('$\chi^2   = 29.6$',xy=(0.02,0.969)),
plt.annotate('reduced $\chi^2 = 1.06$',xy=(0.02,0.961)),
plt.annotate('AIC = 4.6',xy=(0.02,0.953)),
plt.annotate('BIC = 8.9',xy=(0.02,0.945)),
#plt.annotate('AIC = 4.6',xy=(0.02,0.961)),
#plt.annotate('BIC = 8.9',xy=(0.02,0.953)),
#plt.annotate('reduced $\chi^2 = 1.04$',xy=(0.02,0.945)),
plt.annotate('Quadratic Fit - Initial Radius = %0.2f fm'%(np.sqrt(-6*quad_example_result[i].best_values['a1'])-0.81),xy=(0.114,0.942),color=('blue'),zorder=11),
plt.tight_layout()
plt.savefig('frequentist-band.pdf')
plt.show()
